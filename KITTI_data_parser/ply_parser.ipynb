# %%
from plyfile import PlyData
import pandas as pd
import numpy as np

# %%
def read_ply_to_dataframe(file_path):
    with open(file_path, 'rb') as file:
        plydata = PlyData.read(file)

    # Extract data from the plydata object
    data = plydata['vertex'].data

    # Create a dictionary to store the data
    ply_dict = {}
    for name in data.dtype.names:
        ply_dict[name] = data[name]

    # Convert the dictionary to a pandas DataFrame
    df = pd.DataFrame(ply_dict)

    return df

# Replace 'your_ply_file.ply' with the actual path to your PLY file

# %%
df = read_ply_to_dataframe("../data/data_3d_semantics/train/2013_05_28_drive_0000_sync/dynamic/0000010078_0000010362.ply")

# %%
df
# Out:
#                   x            y           z  red  green  blue  semantic  \
# 0       1056.387329  3177.693848  116.197304  255    255   255        26
# 1       1056.380127  3177.762451  116.177597  255    255   255        26
# 2       1056.525513  3177.733643  116.142799  140    142   145        26
# 3       1056.490356  3177.663086  116.097000  255    255   255        26
# 4       1056.394287  3177.763428  116.076797  233    220   210        26
# ...             ...          ...         ...  ...    ...   ...       ...
# 132207  1053.630005  3177.399902  116.285004  128    128   128        26
# 132208  1053.619995  3177.379883  116.285004  128    128   128        26
# 132209  1053.640015  3177.540039  116.282997  128    128   128        26
# 132210  1053.630005  3177.489990  116.283997  128    128   128        26
# 132211  1053.650024  3177.649902  116.281998  128    128   128        26
#
#         instance  visible  timestamp  confidence
# 0          26893        1      10341    0.749400
# 1          26893        1      10341    0.799349
# 2          26893        1      10341    0.829725
# 3          26893        1      10341    0.808272
# 4          26893        1      10341    0.841420
# ...          ...      ...        ...         ...
# 132207     26893        0      10355    1.000000
# 132208     26893        0      10355    1.000000
# 132209     26893        0      10355    1.000000
# 132210     26893        0      10355    1.000000
# 132211     26893        0      10355    1.000000
#
# [132212 rows x 11 columns]

# %%
rows_with_26 = df[df['semantic'] == 26]

# %%
rows_with_26
# Out:
#                   x            y           z  red  green  blue  semantic  \
# 0       1056.387329  3177.693848  116.197304  255    255   255        26
# 1       1056.380127  3177.762451  116.177597  255    255   255        26
# 2       1056.525513  3177.733643  116.142799  140    142   145        26
# 3       1056.490356  3177.663086  116.097000  255    255   255        26
# 4       1056.394287  3177.763428  116.076797  233    220   210        26
# ...             ...          ...         ...  ...    ...   ...       ...
# 132207  1053.630005  3177.399902  116.285004  128    128   128        26
# 132208  1053.619995  3177.379883  116.285004  128    128   128        26
# 132209  1053.640015  3177.540039  116.282997  128    128   128        26
# 132210  1053.630005  3177.489990  116.283997  128    128   128        26
# 132211  1053.650024  3177.649902  116.281998  128    128   128        26
#
#         instance  visible  timestamp  confidence
# 0          26893        1      10341    0.749400
# 1          26893        1      10341    0.799349
# 2          26893        1      10341    0.829725
# 3          26893        1      10341    0.808272
# 4          26893        1      10341    0.841420
# ...          ...      ...        ...         ...
# 132207     26893        0      10355    1.000000
# 132208     26893        0      10355    1.000000
# 132209     26893        0      10355    1.000000
# 132210     26893        0      10355    1.000000
# 132211     26893        0      10355    1.000000
#
# [130962 rows x 11 columns]

# %%
visible_26 = rows_with_26[rows_with_26['visible'] == 1]

# %%
visible_26 = rows_with_26

# %%
import pandas as pd
import numpy as np
from plyfile import PlyData, PlyElement

# Example DataFrame (replace this with your actual DataFrame)


# Convert DataFrame to PLY-friendly format
vertex_count = len(visible_26)
vertex_dtype = [
    ('x', 'f4'),
    ('y', 'f4'),
    ('z', 'f4'),
    ('red', 'u1'),
    ('green', 'u1'),
    ('blue', 'u1'),
    ('semantic', 'i4'),
    ('instance', 'i4'),
    ('visible', 'u1'),
    ('timestamp', 'i4'),
    ('confidence', 'f4'),
]

vertices = np.empty(vertex_count, dtype=vertex_dtype)
vertices['x'] = visible_26['x'].values
vertices['y'] = visible_26['y'].values
vertices['z'] = visible_26['z'].values
vertices['red'] = visible_26['red'].values
vertices['green'] = visible_26['green'].values
vertices['blue'] = visible_26['blue'].values
vertices['semantic'] = visible_26['semantic'].values
vertices['instance'] = visible_26['instance'].values
vertices['visible'] = visible_26['visible'].values
vertices['timestamp'] = visible_26['timestamp'].values
vertices['confidence'] = visible_26['confidence'].values

# Write data to PLY file
ply_filename = 'car.ply'
ply_element = PlyElement.describe(vertices, 'vertex')

# Create PlyData object and save to file
PlyData([ply_element]).write('car.ply')

# %%
import plotly.express as px


def interactivePlot(df):
    #fig = px.scatter_3d(df, x='x', y='y', z='z', color=['rgb({},{},{})'.format(r,g,b) for r,g,b in zip(df.red.values, df.green.values, df.blue.values)])
    fig = px.scatter_3d(df, x='x', y='y', z='z', color="semantic")
    fig.update_traces(marker=dict(size=1))
    fig.update_xaxes(range=[-10000, 10000])
    fig.update_yaxes(range=[-10000, 10000]) 
    fig.update_layout(yaxis_range=[-3,3])
    fig.show()

# %%
df2 = read_ply_to_dataframe("../data/data_3d_semantics/train/2013_05_28_drive_0000_sync/dynamic/0000001980_0000002295.ply")

# %%
df2
# Out:
#                 x            y           z  red  green  blue  semantic  \
# 0      989.987793  3657.305908  115.243500   22     28    17        33
# 1      955.236816  3675.143555  115.267700   40     16    17        33
# 2      886.795898  3692.617920  115.893799  128    148   155        24
# 3      889.303772  3710.722900  115.022499   23     25    27        33
# 4      890.269714  3710.578613  115.186096   48     71   107        25
# ...           ...          ...         ...  ...    ...   ...       ...
# 22108  893.651978  3689.689941  115.769997  128    128   128        24
# 22109  893.616028  3689.610107  115.551003  128    128   128        24
# 22110  893.591003  3689.439941  116.147003  128    128   128        24
# 22111  893.565002  3689.260010  115.753998  128    128   128        24
# 22112  893.562012  3689.399902  116.144997  128    128   128        24
#
#        instance  visible  timestamp  confidence
# 0         33029        1       2346    0.937316
# 1         33029        1       2314    0.923807
# 2         24033        1       2246    0.918915
# 3         33029        1       2237    0.860403
# 4         25002        1       2234    0.904247
# ...         ...      ...        ...         ...
# 22108     24033        0       2292    1.000000
# 22109     24033        0       2292    1.000000
# 22110     24033        0       2292    1.000000
# 22111     24033        0       2292    1.000000
# 22112     24033        0       2292    1.000000
#
# [22113 rows x 11 columns]

# %%
def has_car(df):
    rows_with_13 = df[df['semantic'] == 13]
    return rows_with_13
